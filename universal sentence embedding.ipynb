# %%
import tensorflow_hub as hub
import matplotlib.pyplot as plt
import numpy as np
import os
import pandas as pd
import re
import seaborn as sns

# %% [markdown]
# ## Ordered Sentence Embedding Methods
#
# - Given that non-ordered approaches do not perform well, order sentence embeddings were employed
#
# #### Method 1: Univerasl sentence encoder
# - available through tensorhub https://tfhub.dev/google/universal-sentence-encoder/1
# - Paper: Daniel Cer, Yinfei Yang, Sheng-yi Kong, Nan Hua, Nicole Limtiaco, Rhomni St. John, Noah Constant, Mario Guajardo-Cespedes, Steve Yuan, Chris Tar, Yun-Hsuan Sung, Brian Strope, Ray Kurzweil (2018) https://arxiv.org/abs/1803.11175
#
# #### Method 2: BERT sentence embedding (SBERT)
# - Available through setnence-transformers package https://www.sbert.net/docs/training/overview.html
# - Paper: Nils Reimers, Iryna Gurevych (2019) https://arxiv.org/abs/1908.10084

# %%
import os
os.environ["TFHUB_CACHE_DIR"] = r'J:\Users\JJ\tf_hub'

import tensorflow as tf
import tensorflow_hub as hub
import hashlib

handle = "https://tfhub.dev/google/universal-sentence-encoder/4"
hashlib.sha1(handle.encode("utf8")).hexdigest()


embed = hub.load("https://tfhub.dev/google/universal-sentence-encoder/4")
def get_sentence_embeddings(paragraph_array):
    embeddings=embed(paragraph_array)
    return embeddings
# Out:
# INFO:absl:Using J:\Users\JJ\tf_hub to cache modules.

# %%
def find_and_clean(soup):
    paras = soup.find('div', {'class':'WordSection1'}).find_all('p', {'class':'MsoNormal'})
    out_paras = [p.text.replace('\xa0', ' ').replace('\n', ' ') for p in paras]
    return [p for p in out_paras if p != ' ']


import string
from nltk import word_tokenize
from nltk.corpus import stopwords



def find_and_clean_OPP(f, fdir = "data/OPP/OPP-115/sanitized_policies"):
    with open(os.path.join(fdir, f)) as j:
        soup = BeautifulSoup(j)
    paras = str(soup).split('<br/>')
    paras = [BeautifulSoup(p).text.replace("|||", '') for p in paras]
    paras = [p for p in paras if p != " "]
    paras = [word_tokenize(p) for p in paras]#[p.split(' ') for p in paras]
    exclude = set(string.punctuation)
    stop = set(stopwords.words('english'))
    ans = []
    translator = str.maketrans('','', string.punctuation)
    for clause in paras:
        s = []
        for word in clause:
            if word != "" and word not in stop:
                w = word.translate(translator).strip()
                if w!= '':
                    s.append(w.lower())
        ans.append(s)
               
    return ans


## construct sentence matrix
### (x, y) matrix x = word_embeddings_length, y = number of words; output (x dimension sentence vector)

def construct_mat(sent, model):
    return np.array([model[w] for w in sent])


## word to sentence embeddings 
### (x, y) matrix x = word_embeddings_length, y = number of words; output (x dimension sentence vector)
### According to https://arxiv.org/pdf/1805.09843.pdf; max pooling performs well in sentence comparisons
def SWEM_max(mat):
    return mat.max(axis = 0)


def corpus_mat(corpus, model):
    total_mat = np.empty((len(corpus), model.vector_size))
    for ind, sent in enumerate(corpus):
        sent_mat = construct_mat(sent, model)
        try:
            sent_vec = SWEM_max(sent_mat)
        except:
            print(ind)
            print(sent_mat)
        total_mat[ind, :] = sent_vec
    return total_mat


## similarity
## Given query vector (1, n) and response matrix (m, n), get most similar x vectors, lookup where they are
from sklearn.metrics.pairwise import cosine_similarity
import numpy as np
def sim_query(query, response, query_text, response_text, top_n =5):
    total = np.vstack((query, response))
    #print(total.shape)
    cos_sim = cosine_similarity(total)[0, :]
    #print(cos_sim[:10])
    top_ind = cos_sim.T.argsort()[-(top_n+1):-1][::-1]
    #print(top_ind)
    ans = []
    for j in top_ind.tolist():
        ans.append((cos_sim[j], response_text[j-1]))
    return (query_text, ans)

def print_simquery(simquery):
    print("#"*50)
    print("source: ")
    print(' '.join(simquery[0]))
    print("Top 5  matches: ")
    for j in simquery[1]:
        print('score: ', j[0])
        print(' '.join(j[1]))        
    print("#"*50)

# %%
from bs4 import BeautifulSoup
flist = [f for f in os.listdir('data/htm/') if '.htm' in f]
with open(os.path.join('data/htm/', flist[0])) as f:
    apple_soup = BeautifulSoup(f)

with open(os.path.join('data/htm/', flist[1])) as f:
    default_soup = BeautifulSoup(f)
    
    default_paras = find_and_clean(default_soup)
apple_paras = find_and_clean(apple_soup)

opp_flist = os.listdir("data/OPP/OPP-115/sanitized_policies")

df= []
for i in opp_flist:
    df.extend(find_and_clean_OPP(i))
    
df2 = [a for a in df if len(a) >0]

# %%
embed_imput = [' '.join(a) for a in df2]

# %%
allembeddings = get_sentence_embeddings(embed_imput)

# %%
q = allembeddings[:200 , :]
a = allembeddings[200:, :]

# %%
sq = sim_query(q[50], a, df2[50], df2[200:])

# %%
print_simquery(sq)
# Out:
# ##################################################
# source:
# in course serving advertisements site thirdparty advertiser may place recognize unique cookie browser
# Top 5  matches:
# score:  0.7299808
# in course serving advertisements site thirdparty advertiser may place recognize unique cookie browser if would like information practice know choices information used company please click
# score:  0.7041924
# these companies may place recognize cookies web beacons technology track certain nonpersonal information website users for example course serving certain advertisements advertiser may place recognize unique cookie browser order collect certain information use nyt services for another example advertiser ad server may also able collect device s unique identifier course serving ad in many cases information could used show ads websites based interests
# score:  0.6373111
# some advertisers tulsaworldcom may use cookies when click advertisement visit advertiser s web site make purchase advertiser company may use cookies according policies advertisers cookies covered tulsaworldcom s policy in addition may use third party advertising companies display advertisements website as part service may place separate cookies computer we access control cookies
# score:  0.63277864
# cookies web beacons cookies used store track information a cookie small amount data sent browser web sites stored computer s hard drive cookies used deliver targeted advertising based behavior demographics track entries promotions contests cookies may linked pin in addition medianews uses web beacons provided thirdparty advertising companies help manage online advertising web beacons enable us recognize browser s cookie browser visits medianews web site learn banner ads bring users medianews web sites medianews websites two thirdparty web advertising companies yahoo doubleclick may place recognize unique cookie browser yahoo also may use information regarding users select ads display click learn yahoo s ad practices including opt using anonymous information select ads show for information doubleclick cookies optout please click
# score:  0.63277864
# cookies web beacons cookies used store track information a cookie small amount data sent browser web sites stored computer s hard drive cookies used deliver targeted advertising based behavior demographics track entries promotions contests cookies may linked pin in addition medianews uses web beacons provided thirdparty advertising companies help manage online advertising web beacons enable us recognize browser s cookie browser visits medianews web site learn banner ads bring users medianews web sites medianews websites two thirdparty web advertising companies yahoo doubleclick may place recognize unique cookie browser yahoo also may use information regarding users select ads display click learn yahoo s ad practices including opt using anonymous information select ads show for information doubleclick cookies optout please click
# ##################################################

# %% [markdown]
# ## Compare with BERT

# %%
## bert
import os
os.environ["TFHUB_CACHE_DIR"] = r'J:\Users\JJ\tf_hub'

import tensorflow as tf
import tensorflow_hub as hub
import hashlib

BERThandle = "https://tfhub.dev/tensorflow/bert_en_uncased_L-12_H-768_A-12/2"
hashlib.sha1(BERThandle.encode("utf8")).hexdigest()


BERTembed = hub.KerasLayer("https://tfhub.dev/tensorflow/bert_en_uncased_L-12_H-768_A-12/2")

def get_BERT_embeddings(paragraph_array, array_len = 512):
    embeddings=embed(paragraph_array)
    return embeddings

# %%
## Sentence-transformers: A BERT-based implementation of sentence embeddings
from sentence_transformers import SentenceTransformer, util

# %%
model = SentenceTransformer('distilbert-base-nli-mean-tokens')
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████| 245M/245M [00:42<00:00, 5.73MB/s]

# %%
embed_imput[:5]
# Out:
# ['privacy policy',
#  'scinewscom committed protecting respecting privacy to better inform policy concerning user privacy adopted following terms please note terms subject change changes included page',
#  'information scinewscom may collect online',
#  'scinewscom may collect process following data',
#  'information provide filling forms site including names email website addresses may also ask information purposes example report problem site']

# %%
#Encode all sentences
embeddings = model.encode(embed_imput)

#Compute cosine similarity between all pairs
cos_sim = util.pytorch_cos_sim(embeddings[:200], embeddings[200:])

#Add all pairs to a list with their cosine similarity score
all_sentence_combinations = []
for i in range(len(cos_sim)-1):
    for j in range(i+1, len(cos_sim)):
        all_sentence_combinations.append([cos_sim[i][j], i, j])

# %%
np.array(cos_sim[0].argsort()[-5:])[::-1]
# Out:
# array([1576, 1750, 4863, 1081, 1818], dtype=int64)

# %%
np.array(cos_sim)[0][top_5]
# Out:
# array([1.0000001, 1.0000001, 1.0000001, 1.0000001, 1.0000001],
#       dtype=float32)

# %%
## top 5 from each
top_5_for_each = []
for i in range(len(cos_sim)):
    top_5 = np.array(cos_sim[i].argsort()[-5:])[::-1]
    top_5_for_each.append((np.array(cos_sim)[i][top_5], top_5))

# %%
top_5_for_each[2]
# Out:
# (array([0.89077115, 0.8849205 , 0.88405174, 0.86957514, 0.85734034],
#        dtype=float32),
#  array([3142,  694, 5537, 3844,  675], dtype=int64))

# %%
for k in range(len(top_5_for_each)):
    print("#"*50)
    print("source: ")
    print(embed_imput[k])
    print("Top 5  matches: ")
    for j in range(len(top_5_for_each[k][0])):
        print('Score: ', top_5_for_each[k][0][j])
        print(embed_imput[200+top_5_for_each[k][1][j]])
        
    print("#"*50)
# Out:
# ##################################################
# source:
# privacy policy
# Top 5  matches:
# Score:  1.0000001
# privacy policy
# Score:  1.0000001
# privacy policy
# Score:  1.0000001
# privacy policy
# Score:  1.0000001
# privacy policy
# Score:  1.0000001
# privacy policy
# ##################################################
# ##################################################
# source:
# scinewscom committed protecting respecting privacy to better inform policy concerning user privacy adopted following terms please note terms subject change changes included page
# Top 5  matches:
# Score:  0.89361596
# we occasionally update privacy policy necessary protect users comply changing environment we recommend check posted privacy policy visit sites sure aware understand current policy your continued use respective site means accept updated privacy policy
# Score:  0.8892149
# if modify privacy policy handle personal information post revised information revised effective date top privacy policy if material changes privacy policy use personal information may notify means sending email posting notice changes website we encourage periodically review statement informed protecting information
# Score:  0.87263596
# to better understand uptodate s online privacy policies please read following privacy policy
# Score:  0.86929774
# please note review privacy practices time time practices therefore subject change we ask periodically review page ensure continuing familiarity current version web site s privacy policy to contact us privacy issues report violation web site s privacy policy raise issue regarding web site please email us info worldnowcom
# Score:  0.8679232
# we reserve right make changes privacy policy time if make material change privacy policy notify posting notice change wwwusplaystationcom websites we post changes privacy policy necessary give additional choices regarding changes please check privacy policy time time ensure aware changes your continued use websites scea online portals subject privacy policy signify acceptance privacy policy changes
# ##################################################
# ##################################################
# source:
# information scinewscom may collect online
# Top 5  matches:
# Score:  0.89077115
# you share information us various ways stores online for example share information
# Score:  0.8849205
# other information we collect online
# Score:  0.88405174
# information collected online
# Score:  0.86957514
# some services offered abitacom may collect information accessible customer via website in cases access personal information contacting abitacom described bottom statement alternative means access described service
# Score:  0.85734034
# personal information we collect online
# ##################################################
# ##################################################
# source:
# scinewscom may collect process following data
# Top 5  matches:
# Score:  0.8242332
# fsd service providers collect following information
# Score:  0.81567883
# we may area submit feedback any feedback submit area becomes property may contact information
# Score:  0.81503624
# parties may choose share user content
# Score:  0.8123605
# we may share information reasons described policy we tell
# Score:  0.81082124
# in addition uses identified may use information collect purposes disclosed time collect information pursuant consent
# ##################################################
# ##################################################
# source:
# information provide filling forms site including names email website addresses may also ask information purposes example report problem site
# Top 5  matches:
# Score:  0.8924117
# in certain cases contract companies provide services behalf these service providers may maintain customer databases may hold site users email addresses including
# Score:  0.8898648
# on pages site submit content published make community postings comments suggestions vote we may collect name address email addresses connection activities
# Score:  0.8893542
# we may periodically contact offers information services affiliates including connection accounts online surveys legal notices news stories important information you may opt receiving commercial email messages us following instructions contained email messages
# Score:  0.8853931
# here s works we gather information online activities searches conduct sites pages visit this information may used deliver advertising sites offline example phone email direct mail s customized meet specific interests may
# Score:  0.88515
# we andor service provider partners may collect personal information provide us name mailing address phone number email address credit card number well internet protocol ip address post stories andor comments website
# ##################################################
# ##################################################
# source:
# contact us may keep record correspondence
# Top 5  matches:
# Score:  0.8374891
# we may share information reasons described policy we tell
# Score:  0.8349498
# if contact tulsaworldcom may keep record correspondence
# Score:  0.8211045
# parties may share information
# Score:  0.8169559
# how we secure your information
# Score:  0.8108587
# we may share information
# ##################################################
# ##################################################
# source:
# details visits site including limited traffic data location data weblogs communication data
# Top 5  matches:
# Score:  0.8082013
# the truste program covers information collected websites wwwlyndacom mlyndacom wwwvideo2braincom lyndacom mobile application service platform associated website
# Score:  0.80083513
# we use nonpersonally identifiable information ip addresses demographic information zip codes example tailor site interestslocations users measure traffic within site
# Score:  0.7941072
# device information we collect technical information visit websites use mobile applications services this includes information internet protocol ip address type mobile device use device operating system browser type unique device identifier address referring websites path take websites information session websites
# Score:  0.79044497
# if communicate us regarding website disinformation services collect information provide us communication
# Score:  0.7856138
# ifsabutler collects nonpersonally identifiable information purpose optimizing performance website
# ##################################################
# ##################################################
# source:
# scinewscom knowingly collect solicit personal information anyone age 13 we assume minors 13 years age older received permission parents guardians using website parents guardians may contact us privacy scinewscom questions concerns privacy policy
# Top 5  matches:
# Score:  0.9203713
# our sites directed children age 13 we operate sites compliance children s online privacy protection act knowingly collect use personally identifiable information anyone 13
# Score:  0.91754574
# meredith cares protecting privacy children we wo nt knowingly allow anyone age 13 provide us personally identifying information online children always get permission parents sending personal information if re 13 please register services provide us information
# Score:  0.91375804
# we knowingly collect personally identifiable information children younger 13 years age before registering account use services web site ask minors thirteen years old older parents read privacy policy
# Score:  0.9104843
# our sites apps meant adults we knowingly collect personally identifiable information children 13 if parent legal guardian think child 13 given us information email us you also write us address listed end policy please mark inquiries coppa information request
# Score:  0.89280283
# this website directed children the mrc knowingly collect solicit personally identifiable information children 13 except permitted law if discover received personally identifiable information child 13 delete information servers records promptly
# ##################################################
# ##################################################
# source:
# use cookies
# Top 5  matches:
# Score:  1.0000002
# use cookies
# Score:  1.0000002
# use cookies
# Score:  1.0000002
# use cookies
# Score:  0.97673756
# do use cookies
# Score:  0.97347575
# use of cookies
# ##################################################
# ##################################################
# source:
# scinewscom uses cookie technology a cookie small amount data often includes unique identifier sent computer mobile phone browser websites computer stored devices hard drive a website send cookie browser browsers preferences allow browser permits website access cookies already sent cookies sent websites many websites whenever user visits website order track online traffic flows
# Top 5  matches:
# Score:  0.9359309
# like many websites usagov uses persistent cookie technology a persistent cookie small text file website places web browser gather anonymous summary demographic information remember browser used visit site laterkind like cookie crumbs hence name these cookies uniquely identify browser computer never person in words person uses chrome internet explorer two unique browser cookies assigned one browser person counted two different visitors visits based browsers computers persons we use persistent cookies two ways enhance experience usagov also protecting privacy
# Score:  0.930037
# we may place cookie computer a cookie small amount data often includes anonymous unique identifier sent browser websites computers stored computers hard drive we may use cookies keep track choice language home page preference understand exposure certain internet advertisements use websites gather usage data help us generally improve quality websites there simple procedure browsers allows deny accept cookies you note cookies may necessary provide certain features websites
# Score:  0.92950803
# for purposes use cookies that small text files placed computer s hard drive to help us determine type content sites link length time spend particular area feature services usage services cookies also tell us advertising seen services at certain times may use outside advertising companies display advertisements web site may contain cookies banner ads these banner ads collect information stored advertising company access information
# Score:  0.92722803
# cookies small bits electronic information website sends visitor s browser stored visitor s hard drive like many websites employ cookies certain areas site allow us provide information targeted interests make online experience convenient for example return one websites logging cookies provide information website website remember should disable cookies browser provide screen name password time log additionally advertisements managed third parties may appear site use cookies advertisers use cookies collect nonpersonal information click move cursor one banner advertisements you may realize information collected advertisers use information monitor performance advertisements in cases may access information cookies used advertisers site information may permit us identify sites visited also associated advertisers
# Score:  0.9264551
# acc uses cookies small pieces information sent browser website visit these cookies collect personally identifiable information cookies used track usage patterns traffic trends customer behavior well record information website many content adjustments customer service improvements made based data derived cookies information acc collects cookies used create profiles users used aggregate form
# ##################################################
# ##################################################
# source:
# during course visit scinewscom website pages see along cookie downloaded device a website cookies enable publisher find whether device visited website this done repeat visit checking see finding cookie left last visit
# Top 5  matches:
# Score:  0.9004595
# we use cookies store visitors preferences record session information record userspecific information pages visitors visit customize webpage content visitors browser type information visitor sends show dcccd ads people previously visited website how view information
# Score:  0.8993016
# ifsabutler uses cookies purpose maintaining session provide information ifsabutler web forms application system cookies small pieces information transferred website web browser streamline experience website allow web servers recognize computer used access website our website use cookies collect personally identifiable information you modify browser settings decline cookies wish opt service
# Score:  0.8894401
# what cookies a cookie textonly string information website transfers cookie file browser computer s hard disk website recognize revisit remember certain information this include pages visited choices made menus specific information entered forms time date visit types cookies there two main types cookies session cookies temporary cookies expire end browser session leave site session cookies allow website recognize navigate pages single browser session allow use website efficiently for example session cookies enable website remember user placed items online shopping basket persistent cookies contrast session cookies persistent cookies stored equipment browsing sessions expiry deletion they therefore enable website recognize return remember preferences tailor services in addition session cookies persistent cookies may cookies set website chosen visit website order provide us third parties information our use cookies we currently use may use future following types cookies website we use session cookies
# Score:  0.87871176
# like websites site uses cookies keep track purchases activity site enhance experience site we also use cookies deliver content specific interests save password choose save information reenter time visit site if wish disable cookies help portion toolbar browsers tell however set browser disable cookies may able access certain areas site
# Score:  0.8782971
# cookies gifs logs cookies small text files website place visitor s computer hard drive recognize repeat visitors facilitate visitor s use site track visitor s access use site
# ##################################################
# ##################################################
# source:
# please note visits scinewscom website may notice cookies related scinewscom control dissemination cookies you must check third party websites information
# Top 5  matches:
# Score:  0.9098365
# your access web sites affected accept cookies served third parties
# Score:  0.90862095
# your access websites affected accept cookies served third parties
# Score:  0.9080895
# please understand barnes noble control third party cookies check privacy policies third party advertising networks see whether uses cookies
# Score:  0.90164495
# in course serving advertisements site thirdparty advertiser may place recognize unique cookie browser if would like information practice know choices information used company please click
# Score:  0.89205
# ii some third party partners including advertisers marketing services companies may set access cookies similar technologies computer well may behalf we control third parties use cookies similar technologies information derived therefrom
# ##################################################
# ##################################################
# source:
# you may refuse accept cookies activating setting browser allows refuse setting cookies however select setting may unable access certain parts site
# Top 5  matches:
# Score:  0.8639475
# you may opt accepting cookies changing settings browser however rejecting cookies may prevent using certain functions may repeatedly enter information take advantage services promotions
# Score:  0.86173975
# you generally prevent cookies used changing settings web browser please aware may unable fully utilize site
# Score:  0.8508947
# you refuse accept cookies devices browsers offer privacy settings cookies you need manage cookie settings device browser use however accept cookies may experience inconvenience use site online products services for example able recognize device need answer challenge question time log you also may receive tailored advertising offers us may relevant interests needs
# Score:  0.84461206
# your browser device may include do not track functionality because do not track compliance protocol yet finalized the atlantics information collection disclosure practices choices provide customers continue operate described privacy policy whether do not track signal received
# Score:  0.8263457
# certain web browsers may provide option may ask browser inform websites visit wish activities tracked cookies persistent identifiers commonly called do not track signals although barnes noble websites currently unable respond do not track signals may opt tracking activities bv following instructions privacy policy opt ibm coremetrics behavioral advertising
# ##################################################
# ##################################################
# source:
# disclosure your information
# Top 5  matches:
# Score:  0.9899801
# disclosure of your information
# Score:  0.9230549
# disclosure information
# Score:  0.9224401
# use disclose collected information
# Score:  0.9159167
# we use information disclosed described
# Score:  0.91305375
# information you give us
# ##################################################
# ##################################################
# source:
# scinewscom sell trade rent personal information third parties if choose future notified email intentions right removed prior disclosure
# Top 5  matches:
# Score:  0.85886675
# d marketing provided third parties from time time may disclose contact information third parties allow market products services marketing purposes this may information received offline online if want us stop sharing email contact information third parties email contact information may notify us https preferenceshearstmagscomhearstloginaspxif want us stop sharing postal mailing contact information third parties postal address may notify us writing sending notice mail preference service po box 6000 harlan iowa 51593 contacting us customercare hearstmagscom if wish opt information shared marketing services companies please see section 4 in case marketing via paid video subscription services please refer customer service contact set forth section 4 e please follow instructions provided third parties unsubscribe messages
# Score:  0.8561513
# we may share email address thirdparty media agency send interestbased advertising behalf we may also share aggregated deidentified information including based email address advertising marketing partners thirdparty media platforms including social media sites allow send targeted advertising messages andor conduct analyses behalf if wish stop receiving advertising messages third parties please review your choices section in addition may able opt ads clicking icon ad privacy settings social media platform
# Score:  0.8556852
# if prefer receive traditional mail offline promotions time inc property want optout sharing personally identifiable offline information third parties owned time inc please click
# Score:  0.8556852
# if prefer receive traditional mail offline promotions time inc property want optout sharing personally identifiable offline information third parties owned time inc please click
# Score:  0.8529132
# you update contact information provide us using my account feature available many sites emailing us privacy meredithcom you stop delivery commercial email messages receive meredith brand using unsubscribe link email receive you remove name postal address lists sell rent third parties direct marketing purposes using optout form you optout use online viewing behavior data serve interestbased advertising thirdparty sites email newsletters wwwaboutadsinfo clicking ad choices link footer websites navigating consumer optout page use links optout interestbased advertising services thirdparty advertising networks may use other information
# ##################################################
# ##################################################
# source:
# your consent rights
# Top 5  matches:
# Score:  0.9283512
# with your consent
# Score:  0.9053199
# consent
# Score:  0.8911494
# otherwise with your consent at your direction
# Score:  0.8874927
# with consent
# Score:  0.8554607
# your choices
# ##################################################
# ##################################################
# source:
# by using scinewscom consent collection use accordance policy information provide us
# Top 5  matches:
# Score:  0.80154973
# lyndacom privacy practices described policy comply apec cross border privacy rules system
# Score:  0.7956827
# we ask consent using information purpose set privacy policy
# Score:  0.79395187
# our information sharing practices
# Score:  0.7914454
# questions about policy access your information
# Score:  0.7859603
# opensecretsorg privacy policy
# ##################################################
# ##################################################
# source:
# we remove personally identifiable information records request contact us request privacy scinewscom
# Top 5  matches:
# Score:  0.8402096
# you right terminate account update personal information collected sites contacting us feedback highgearmediacom if terminate account personal information removed system subject right retain data necessary investigate violation terms use alleged harmful illegal activity
# Score:  0.837097
# we retain personal information account us thereafter long need purposes prohibited applicable laws thereafter either delete personal information deidentify anonymous attributed identity your rights request delete personal information set forth accessing correcting deleting your personal information section
# Score:  0.837097
# we retain personal information account us thereafter long need purposes prohibited applicable laws thereafter either delete personal information deidentify anonymous attributed identity your rights request delete personal information set forth accessing correcting deleting your personal information section
# Score:  0.81766117
# we responsible personally identifiable information choose submit forums responsibility publish remove edit comments conversations content for information see tedcom terms use
# Score:  0.8077386
# information submit web site used contact subscribed newsletter made donation respond action request made center should unsubscribe newsletter permanently removed contact list
# ##################################################
# ##################################################
# source:
# contact us
# Top 5  matches:
# Score:  1.000001
# contact us
# Score:  1.000001
# contact us
# Score:  1.000001
# contact us
# Score:  1.000001
# contact us
# Score:  0.97879374
# contacting us
# ##################################################
# ##################################################
# source:
# if inquiries privacy policy implementation may contact us privacy scinewscom
# Top 5  matches:
# Score:  0.89150846
# questions regarding privacy policy directed us info worldnowcom
# Score:  0.8749894
# terms use privacy policy privacy policy advertising addendum security contact us
# Score:  0.8469407
# if questions concerns privacy policy contact us
# Score:  0.8450355
# if questions regarding privacy policy may contact us using information
# Score:  0.8446885
# if re outside united states information sent stored united states servers located by using sites apps agree information collection use sharing practices described privacy policy
# ##################################################
# ##################################################
# source:
# redorbit inc privacy statement
# Top 5  matches:
# Score:  0.87923163
# opensecretsorg privacy policy
# Score:  0.87412095
# changes to privacy statement
# Score:  0.87280554
# reddit privacy policy
# Score:  0.8591885
# changes privacy statement
# Score:  0.8591885
# changes privacy statement
# ##################################################
# ##################################################
# source:
# this privacy statement covers site newwwwredorbitcom because web site wants demonstrate commitment users privacy agreed disclose information practices
# Top 5  matches:
# Score:  0.8968129
# ifsabutler committed respecting privacy protecting information receive this policy intended outline information collect users visit submit applications website use disclose information
# Score:  0.861555
# esrb privacy online thirdparty seal provider whose mission protect consumers online privacy make internet secure reliable private place share information conduct business esrb privacy online promotes enforces established principles guidelines fair information collection practices include requirements full disclosure notice informed consent
# Score:  0.86096466
# this privacy policy web sites owned operated freedom communications inc freedom including without limitation web sites listed collectively site we respect privacy appreciate confidence placed site we committed protecting privacy preserving trust please carefully review privacy policy learn collect use protect personal information provide us choices managing personal information this privacy policy subject user agreement posted site
# Score:  0.857382
# abita committed protecting privacy by accessing website consenting information collection use practices described privacy statement
# Score:  0.85038996
# this privacy policy covers sites kinja platform created owned kinja kft kinja us the privacy policy governs access use services websites applications offered kinja services please read statement carefully using proceeding access kinja your use kinja indicates read understood privacy policy indicates agreement abide terms use effect subject policy
# ##################################################
# ##################################################
# source:
# what personally identifiable information redorbit inc collects
# Top 5  matches:
# Score:  0.8787426
# we collect personally identifying information connection following
# Score:  0.8718308
# how do we secure your personally identifiable information
# Score:  0.85713816
# your submission others personally identifiable information
# Score:  0.85298467
# vii how do we secure your personally identifiable information
# Score:  0.8499454
# we collect maintain personally identifiable information automatic information
# ##################################################
# ##################################################
# source:
# what personally identifiable information third parties collect web site
# Top 5  matches:
# Score:  0.8642417
# social networking third party sites
# Score:  0.86424166
# social networking third party sites
# Score:  0.8630271
# you choices collection information third parties website
# Score:  0.86164045
# disclosure third party service providers online partners
# Score:  0.8594337
# does this privacy policy apply when i access third party websites
# ##################################################
# ##################################################
# source:
# what organization collects information
# Top 5  matches:
# Score:  0.8717227
# how we collect information
# Score:  0.860379
# what information collect use
# Score:  0.857704
# what information we collect how we use it
# Score:  0.8554878
# what types of information do we collect
# Score:  0.8554878
# what types of information do we collect
# ##################################################
# ##################################################
# source:
# how redorbit inc uses information
# Top 5  matches:
# Score:  0.85316753
# how we use information
# Score:  0.85316753
# how we use information
# Score:  0.85316753
# how we use information
# Score:  0.8531674
# how we use information
# Score:  0.8531674
# how we use information
# ##################################################
# ##################################################
# source:
# with redorbit inc may share user information
# Top 5  matches:
# Score:  0.9188717
# parties may choose share user content
# Score:  0.87639713
# parties may share information
# Score:  0.8578858
# by using sites agree may share personal information following ways
# Score:  0.85742164
# you may access change modify your personal information
# Score:  0.8566872
# with information may shared
# ##################################################
# ##################################################
# source:
# what choices available users regarding collection use distribution information
# Top 5  matches:
# Score:  0.80414957
# what choices collection use information
# Score:  0.7851837
# how can you make choices about the information that we collect about you
# Score:  0.7821905
# transfer your information event sale acquisition
# Score:  0.7764774
# what information we collect how we use it
# Score:  0.7749828
# ii what do we do with collected information
# ##################################################
# ##################################################
# source:
# what types security procedures place protect loss misuse alteration information redorbit inc control
# Top 5  matches:
# Score:  0.8099062
# what kind of security procedures are in place to protect the loss misuse or alteration of information under the company s control
# Score:  0.80488664
# we take security measures protect personal information maintain theft unauthorized access alteration
# Score:  0.7992007
# in order line fair information practices take following responsive action data breach occur
# Score:  0.7854888
# protect fraud illegal activity risk management purposes
# Score:  0.7799847
# security retention storage information
# ##################################################
# ##################################################
# source:
# how users correct inaccuracies information
# Top 5  matches:
# Score:  0.8208724
# how to optout correct your information
# Score:  0.7883938
# how does disinformation use my information
# Score:  0.78177065
# how when does disinformation collect this information
# Score:  0.77851593
# diagnose fix technology problems
# Score:  0.7696415
# you may also request inaccuracies corrected information maintain record
# ##################################################
# ##################################################
# source:
# information collection use
# Top 5  matches:
# Score:  0.9999995
# information collection use
# Score:  0.97426236
# collection use of information
# Score:  0.9649276
# information collection and use
# Score:  0.95012605
# collection information
# Score:  0.9495467
# use of information collected
# ##################################################
# ##################################################
# source:
# information collection
# Top 5  matches:
# Score:  0.9703047
# information collection use
# Score:  0.96055186
# collection information
# Score:  0.95764416
# collection use of information
# Score:  0.9397492
# information collect
# Score:  0.9397492
# information collect
# ##################################################
# ##################################################
# source:
# redorbit inc sole owner information collected redorbitcom redorbit inc collects information users several different points web site
# Top 5  matches:
# Score:  0.8256019
# our web advertising partners send us aggregate anonymous information visits site number times visitors clicked particular advertisement visitors names addresses personal information
# Score:  0.8157095
# if registered account one web sites track aggregate public activities web site by choosing participate public activities electing share display public activities via web sites furthermore public activities may included rss feeds apis made available websites via formats as result public activities may appear websites blogs feeds be aware responsible personal information choose make public via public activities agree sharing deemed done sidearm sports
# Score:  0.80081296
# the newspost may make use refer userposted content purposes promoting randall family llc publications print online the newspost makes claim ownership userposted content
# Score:  0.7949475
# personal information information identifies may used contact online offline the company collects personal information voluntary basis when submit personal information company usually take form registration online services websites jobs products contests special events subscribing newsletters alerts posting commenting message boards forums news blogs chat rooms online services purchasing product services online stores purchasing dlc virtual items virtual currency use software andor online services using tell friend email page ecard features requesting technical support downloading demos programs software participating polls surveys questionnaires otherwise use software including console products mobile products personal computer products use online products online services personal information required use andor participation the types information collected connection activities listed vary depending activity the information collect may include personal information first andor last name email address phone number photo mailing address payment information in addition may collect demographic nonpersonal information systems age gender date birth zip code hardware configuration console id software products played survey data purchases ip address systems played if information collected activity also requires personal information may combine information personal information prize winners may required provide additional information prize fulfillment
# Score:  0.79317516
# we may match andor combine information collected connection various online services display publicly including websites games multiplayer game lobbies for example associate company website account game console account ingame achievements may displayed combining website account name ingame achievements
# ##################################################
# ##################################################
# source:
# registration
# Top 5  matches:
# Score:  0.9999998
# registration
# Score:  0.9427629
# registration information
# Score:  0.9427629
# registration information
# Score:  0.9427629
# registration information
# Score:  0.89454377
# application
# ##################################################
# ##################################################
# source:
# in order use web site user must first complete registration form during registration user required give contact information name email address we use information contact user services site expressed interest it optional user provide demographic information income level gender unique identifiers username password encouraged provide personalized experience site
# Top 5  matches:
# Score:  0.8567408
# web site user registration user registration required access majority content services features medianews web sites upon registration require provide email address first name username password allow change pin needed user registration medianews web sites completed membership activated upon clicking link emailed address provided registration at time opportunity optin email newsletters alerts email offers sent behalf medianews advertisers however update preferences later time
# Score:  0.8567408
# web site user registration user registration required access majority content services features medianews web sites upon registration require provide email address first name username password allow change pin needed user registration medianews web sites completed membership activated upon clicking link emailed address provided registration at time opportunity optin email newsletters alerts email offers sent behalf medianews advertisers however update preferences later time
# Score:  0.8344119
# registration forms our site s registration form requires users give us contact information like name email address financial information like account credit card numbers demographic information like zip code state we use customer contact information registration form send user information company the customer s contact information also used contact visitor necessary users may optout receiving future emails see choiceoptout section financial information collected used check users qualifications registration demographic profile data also collected site we use data help us improve website service
# Score:  0.8302881
# b the service generally collects personally identifiable information specific knowledge consent for instance enter sweepstakes contest complete survey make purchase subscribe publication register certain services register andor set accountprofile access visit andor use certain portions service service whole may provided required choose password andor user id may provide credit debit charge card number payment information well name telephone number email andor street address personally identifiable information other information age gender avatar number mobile device may also requested in addition may asked send us similar information via messaging eg email sms mms technologies all information shall referred privacy policy registration information
# Score:  0.82896537
# we ask need information personally identifies personal information allows us contact provide service carry transaction requested receiving information abita products services entering contest ordering email newsletters joining limitedaccess premium site service purchasing downloading andor registering abita products the personal information collect may include name title company organization name work email work phone work home address information job function information company information circumstances related purchase payment information
# ##################################################
# ##################################################
# source:
# order
# Top 5  matches:
# Score:  0.8971405
# overview
# Score:  0.8971405
# overview
# Score:  0.8740121
# notice
# Score:  0.8559098
# essence
# Score:  0.8484462
# member
# ##################################################
# ##################################################
# source:
# we request information user order form a user must provide contact information name email shipping address financial information credit card number expiration date this information used billing purposes fill customer s orders if trouble processing order information used contact user
# Top 5  matches:
# Score:  0.89305055
# when ordering registering site appropriate may asked enter name email address mailing address credit card information details help experience
# Score:  0.88258874
# we collect personal information purpose respond request the personal information collect decide give us ordering publications sending us email subscribing email subscription services if choose provide us personal information like filling contact us form email address zip code submitting us website use information respond message help get information requested similarly order publication us collect name mailing address fulfill order
# Score:  0.8657545
# we ask need information personally identifies personal information allows us contact provide service carry transaction requested receiving information abita products services entering contest ordering email newsletters joining limitedaccess premium site service purchasing downloading andor registering abita products the personal information collect may include name title company organization name work email work phone work home address information job function information company information circumstances related purchase payment information
# Score:  0.85827446
# registration forms our site s registration form requires users give us contact information like name email address financial information like account credit card numbers demographic information like zip code state we use customer contact information registration form send user information company the customer s contact information also used contact visitor necessary users may optout receiving future emails see choiceoptout section financial information collected used check users qualifications registration demographic profile data also collected site we use data help us improve website service
# Score:  0.84761643
# when place order product service need know sort information typically used credit card transactions name mailing billing addresses shipping address different telephone number credit card number expiration date gathering information allows us process fulfill order notify order status we also use information contact regarding order necessary we encrypt information using secure socket layers ssl technology
# ##################################################
# ##################################################
# source:
# information use
# Top 5  matches:
# Score:  0.97450215
# information collection use
# Score:  0.97202474
# use of information
# Score:  0.9597094
# uses information
# Score:  0.95684826
# information collection and use
# Score:  0.95272565
# collection use of information
# ##################################################
# ##################################################
# source:
# profile
# Top 5  matches:
# Score:  0.86584735
# links
# Score:  0.86584735
# links
# Score:  0.86584735
# links
# Score:  0.86584735
# links
# Score:  0.86584735
# links
# ##################################################
# ##################################################
# source:
# we store information collect cookies log files clear gifs andor third parties create profile users a profile stored information keep individual users details viewing preferences consequently collected information tied users personally identifiable information provide offers improve content site user this profile used tailor user s visit web site direct pertinent marketing promotions we share profile third parties
# Top 5  matches:
# Score:  0.93411225
# we also engage third parties track analyze nonpersonally personally identifiable website data to permit third parties apply cookies users services permitted law subject right optout network advertising initiative discussed we use data collected third parties help us administer improve quality services analyze use services we also use third parties assist us serving advertisements such third parties may combine information provide information collected see http newsbustersorgprivacypolicy sthash3setplfkdpuf
# Score:  0.9232289
# we partner third party ad networks manage advertising sites as part service use cookies clear gifs we provide thirdparty ad server personally identifiable information information purchases we third party ad server collect use ip address certain nonpersonally identifiable information browser type server computer logged onto area code zip code associated server whether responded particular advertisement if wish information used purpose serving targeted ads may optout clicking please note opt served advertising you continue receive generic ads
# Score:  0.91569877
# we also use thirdparty advertising companies present ads sites advertise thirdparty advertising technology uses information derived visits web site sites advertise present ads uses cookies track activity we also use web beacons provided thirdparty advertising companies web site sites help manage optimize online advertising web beacons enable us recognize browser s cookie browser visits site learn banner ads bring users web site enable us deliver relevant ads users to optout time please click
# Score:  0.9138534
# we allow thirdparty companies serve ads andor collect certain anonymous information visit web site these companies may use nonpersonally identifiable information eg click stream information browser type time date subject advertisements clicked scrolled visits web sites order provide advertisements goods services likely greater interest these companies typically use cookie third party web beacon collect information to learn behavioral advertising practice optout type advertising visit networkadvertisingorg
# Score:  0.9132614
# we allow select third parties deliver advertisements content social networking provide services associated services set cookies web beacons similar technologies certain locations within services certain emails sent us third party companies manage deliver advertisements websites applications commonly referred network advertisers a permitted network advertiser may use cookies web beacons similar technologies collect information interaction services order tailor certain advertisements content delivered within services websites within network advertiser s ad network you may elect opt targeted behavioral advertising many major third party network advertisers clicking if would like obtain information common industry practices network advertisers make choices use information find additional optout tools operated advertising industry associations encompassing even network advertisers please click
# ##################################################
# ##################################################
# source:
# cookies
# Top 5  matches:
# Score:  1.0000005
# cookies
# Score:  1.0000005
# cookies
# Score:  1.0000005
# cookies
# Score:  1.0000005
# cookies
# Score:  1.0000005
# cookies
# ##################################################
# ##################################################
# source:
# a cookie piece data stored user s computer tied information user usage cookie way linked personally identifiable information site we use session id cookies persistent cookies for session id cookie users close browser cookie simply terminates a persistent cookie small text file stored user s hard drive extended period time persistent cookies removed following internet browser help file directions
# Top 5  matches:
# Score:  0.9217253
# cookies information when visit website may send one cookies small text file containing string alphanumeric characters computer mobile device local device storage uniquely identifies browser device allows company help log faster enhance navigation website a cookie collect personal information individual identity established company uses session cookies persistent cookies a persistent cookie remains local device storage close browser persistent cookies may used browser subsequent visits service persistent cookies removed following web browser s local device storage s directions a session cookie temporary disappears close browser you set web browser refuse cookies indicate cookie sent therefore features service may function properly ability accept cookies disabled other cookies collect information browsing habits order help us advertisers make suggestions relevant interests they remember websites visited information shared parties advertisers for example use third parties provide personalized advertisements visiting websites you change settings browser local device storage prevent cookies stored local device storage without explicit consent your browser help section normally provide details manage cookie settings
# Score:  0.9136127
# a cookie small amount data sent browser internet server stored computer jibjab uses cookies including flash cookies store user preferences account status traffic origination record session information purposes including ensuring users repeatedly offered advertisements customize newsletter advertising web page content based browser type user profile information you may able configure browser accept reject cookies flash cookies notify cookie flash cookie set browser different check help menu browser learn change cookie preferences however must enable cookies jibjab order use functions jibjab sites for information flash cookies remove computer please see paragraph entitled special note flash cookies
# Score:  0.9083136
# srl may place internet cookies visitors hard drives internet cookies save data individual visitors visitor s name password username shopping cart screen preferences pages site viewed visitor when visitor revisits site srl may recognize visitor internet cookie customize visitor s experience accordingly example prefilling forms visitors may decline remove internet cookies using appropriate feature web client software available
# Score:  0.9073471
# ...
# Score:  0.83797306
# california s shine light law civil code section 179883 requires certain businesses respond requests california customers asking businesses practices related disclosing personal information third parties third parties direct marketing purposes alternately businesses may place policy disclose personal information customers third parties third parties direct marketing purposes customer exercised option optout informationsharing note time inc sites recognize track signals browsers may employ as discussed wish optout sharing information third parties third parties direct marketing purposes offline please click email please click to find optout rights please contact us described how contact us section
# Score:  0.8268423
# partners we license api partners use develop geocachingrelated services including websites mobile applications any information included public profile geocache logs including photos accessible api additionally share home coordinates api partners randomize decimal portion degrees our api license agreement requires api partners comply terms privacy policy regard information acquired api submitted use websites mobile applications we provide location information map providers without identifying specifically purpose enabling map functionality additionally may partner companiesorganizations provide promotions geotours geocaching adventures if choose participate information provide may shared via api otherwise enable participation allow sponsor contact
# Score:  0.826583
# financing tools apply online preapproved credit if choose submit application acura financial services preapproved credit request provide personally identifiable information name address telephone number social security number date birth employment information gross monthly income this information collected used manner appropriate process request preapproved credit for example american honda finance corporation business acura financial services may use information investigate credit employment income assist credit decisionmaking process after apply may also check status application in order request provide name zip code personal identification number we also encourage review american honda finance corporation financial privacy policy learn protections use nonpublic personal information namely personally identifiable financial information
# ##################################################
# ##################################################
# source:
# security
# Top 5  matches:
# Score:  1.0000008
# security
# Score:  1.0000008
# security
# Score:  1.0000008
# security
# Score:  1.0000008
# security
# Score:  1.0000008
# security
# ##################################################
# ##################################################
# source:
# american honda reasonable security measures place protect personally identifiable information this information protected transmitted secured sockets layer ssl connection most web pages display personally identifiable information encrypted using 128bit ssl industry standard the following brands brochure requests however transmitted ssl connection engine marine power equipment in addition motorcycle brand site currently transmit brochure email notification requests ssl connection in addition security procedures policies place safeguard loss theft unauthorized access destruction misuse modification information receive however perfect security exist internet if ownershondacomownersacuracom registrant help protect personally identifiable information selecting log out icon close browser
# Top 5  matches:
# Score:  0.8303853
# my vehicle honda ownersacura owners provides access valuable resources like maintenance schedules roadside tips faqs account management if choose register honda ownersacura owners asked set honda idacura id password you required submit email address send password information case forget your email address also used send messages relating communication preferences choose set example may choose receive messages us relating general information honda ownersacura owners site updates you may also choose receive messages you also asked tell us make year model trim color year purchased this information used set account specific vehicle you able edit delete vehicle information time
# Score:  0.82084537
# 7 security your personally identifiable information we use variety industrystandard security technologies procedures help protect personallyidentifiable information unauthorized access use disclosure we also require enter password access registration information please disclose registration password unauthorized people no method transmission internet method electronic storage 100 secure however therefore hearst uses reasonable efforts protect personally identifiable information hearst guarantee absolute security
# Score:  0.8190426
# if use estore purchase products online personally identifying information used complete transactions enter including credit card processing independent repair facilities credit checks credit services debt collection your name address email address telephone number applicable credit card information purchase details provided participating hondaacura dealer choose fulfill order honda acura dealers independent american honda we installed safeguards secure protect credit card information used transactions
# Score:  0.81690735
# thank interest websites services privacy information this privacy policy applies following websites owned operated high gear media inc the car connection wwwthecarconnectioncom motor authority wwwmotorauthoritycom green car reports wwwgreencarreportscom site together high gear media sites because high gear media sites share common platform registration system information provide one site may used visit one sites listed
# Score:  0.8153946
# the personally identifying information pin gathered medianews medianews web sites generally includes email address password zip code age gender whether print subscriber may also include name andor company name street address date birth phone numbers credit card numbers billing information necessary contact process web site purchases medianews may also collect information household income job title personal interests hobbies the pin collected depends page visiting services participate
# ##################################################
# ##################################################
# source:
# do not track signals
# Top 5  matches:
# Score:  0.9535485
# do not track disclosure
# Score:  0.9535485
# do not track disclosure
# Score:  0.9444792
# do not track
# Score:  0.94447917
# do not track
# Score:  0.91731346
# how respond do not track disclosures
# ##################################################
# ##################################################
# source:
# our websites treat browsers send track signal differently browsers send one
# Top 5  matches:
# Score:  0.7566353
# cookies web beacons used disinformation online partners linked personal information
# Score:  0.74656165
# if one sites sold transferred another company personal information also transferred we notify information subject different privacy policy
# Score:  0.7462017
# you contact site administrator webmaster external sites concerns regarding matter related available external sites including without limitation privacy practices sites
# Score:  0.74357116
# who should use our web site
# Score:  0.74291325
# company reserves right obligation monitor user content post website company right remove user content reason reason including without limitation sole opinion user content violates may violate applicable law terms use incorporated herein reference protect defend company s rights property third party company also reserves right remove user content upon request third party
# ##################################################
# ##################################################
# source:
# links
# Top 5  matches:
# Score:  0.99999964
# links
# Score:  0.99999964
# links
# Score:  0.99999964
# links
# Score:  0.99999964
# links
# Score:  0.99999964
# links
# ##################################################
# ##################################################
# source:
# our web sites may contain links sites however please aware access links leaving site as result encourage users read privacy policies sites responsible content links privacy procedures
# Top 5  matches:
# Score:  0.92450434
# our web sites may contain links websites convenience information we responsible privacy practices content websites
# Score:  0.90968335
# in addition website includes links websites whose privacy practices may differ barnes noble if submit personal information sites information governed privacy policies we encourage carefully read privacy policy website visit
# Score:  0.9003043
# if comment question privacy policy please contact guest services our sites applicationsmay contain links sites owned controlled us responsible privacy practices sites we encourage aware leave sites applications read privacy policies sites may collect personal information
# Score:  0.89746535
# the disinformation company ltd disinformation values users website website your privacy trust important us we recognize may concerned collection use disclosure personally identifiable information personal information collect use website services offered website disinformation services this privacy policy describes information collect collect information collect by using website accepting practices described privacy policy if questions comments regarding privacy policy please contact us using contact form
# Score:  0.8885454
# websites link services may collect personal information including social networking sites choose link account us this privacy policy apply control activities sites
# ##################################################
# ##################################################
# source:
# policy updates
# Top 5  matches:
# Score:  0.92785823
# what update policy
# Score:  0.883473
# policy changes
# Score:  0.87013507
# updates this policy
# Score:  0.863072
# our policy outlines
# Score:  0.8615536
# what policy tracking
# ##################################################
# ##################################################
# source:
# if decide change privacy policies procedures post changes privacy policy users always aware information collect use circumstances disclose we suggest periodically visiting page review policies procedures
# Top 5  matches:
# Score:  0.93224764
# whenever kinja changes privacy policy post changes privacy policy page places deem appropriate users always aware information collect use circumstances disclose the prior version privacy policy found version found ve made recent changes you responsible reviewing becoming familiar changes agreement
# Score:  0.89574105
# if modify privacy policy handle personal information post revised information revised effective date top privacy policy if material changes privacy policy use personal information may notify means sending email posting notice changes website we encourage periodically review statement informed protecting information
# Score:  0.89566934
# we reserve right modify contents privacy policy needed all changes policy posted ifsabutler website we encourage periodically review policy remain date privacy practices
# Score:  0.8849263
# we reserve right amend privacy policy time any amendments policy may apply information collect future well information obtained prior amendment we post changes policy sites encourage visitors users sites check policy time time
# Score:  0.88474727
# please note review privacy practices time time practices therefore subject change we ask periodically review page ensure continuing familiarity current version web site s privacy policy to contact us privacy issues report violation web site s privacy policy raise issue regarding web site please email us info worldnowcom
# ##################################################
# ##################################################
# source:
# specific web site provisions
# Top 5  matches:
# Score:  0.8680972
# what links web sites
# Score:  0.86057997
# website content
# Score:  0.85933197
# contacting web site
# Score:  0.856384
# how sites use share information
# Score:  0.8533811
# linked websites services
# ##################################################
# ##################################################
# source:
# this section addresses sites unique functionality offerings specific particular areas site serves supplement general provisions
# Top 5  matches:
# Score:  0.81358016
# we additional specific notices personal information practices related specialized operations for example
# Score:  0.8060362
# i which sites are covered by this policy
# Score:  0.7973304
# to customize content available services
# Score:  0.7967253
# inform important information regarding site products services apply may interested applying already enrolled changes terms conditions policies andor administrative information
# Score:  0.7963898
# the personally identifiable information provide us using site may used provide products services enhance experience site applicable enhance experience subscriber the hill s products services
# ##################################################
# ##################################################
# source:
# acura
# Top 5  matches:
# Score:  1.000001
# acura
# Score:  0.86168396
# estore
# Score:  0.84108937
# esrb
# Score:  0.84108937
# esrb
# Score:  0.83320445
# hipaa
# ##################################################
# ##################################################
# source:
# honda powersports
# Top 5  matches:
# Score:  0.9999995
# honda powersports
# Score:  0.9263123
# honda power equipment
# Score:  0.91466886
# honda engines
# Score:  0.8800231
# honda marine
# Score:  0.8761157
# honda automobiles
# ##################################################
# ##################################################
# source:
# hrca clubhouse
# Top 5  matches:
# Score:  1.0000005
# hrca clubhouse
# Score:  0.738526
# support clubpenguincom
# Score:  0.73034394
# info lodgemfgcom
# Score:  0.70652884
# registration
# Score:  0.7043149
# attn general counsel
# ##################################################
# ##################################################
# source:
# honda power equipment
# Top 5  matches:
# Score:  1.0000004
# honda power equipment
# Score:  0.9388118
# honda engines
# Score:  0.92631245
# honda powersports
# Score:  0.8787231
# honda automobiles
# Score:  0.8643937
# honda marine
# ##################################################
# ##################################################
# source:
# honda marine
# Top 5  matches:
# Score:  0.9999998
# honda marine
# Score:  0.8826832
# honda engines
# Score:  0.8800231
# honda powersports
# Score:  0.8643937
# honda power equipment
# Score:  0.86270607
# honda automobiles
# ##################################################
# ##################################################
# source:
# honda engines
# Top 5  matches:
# Score:  1.0000007
# honda engines
# Score:  0.9388118
# honda power equipment
# Score:  0.92195845
# honda automobiles
# Score:  0.9146689
# honda powersports
# Score:  0.8826832
# honda marine
# ##################################################
# ##################################################
# source:
# honda ownersacura owners
# Top 5  matches:
# Score:  0.9999999
# honda ownersacura owners
# Score:  0.81370914
# honda titling inchonda lease trust
# Score:  0.8100967
# honda powersports
# Score:  0.8035791
# hondafinancialservicescom
# Score:  0.8035791
# hondafinancialservicescom
# ##################################################
# ##################################################
# source:
# estore
# Top 5  matches:
# Score:  0.99999964
# estore
# Score:  0.90256214
# essence
# Score:  0.8690554
# esrb
# Score:  0.8690554
# esrb
# Score:  0.86721814
# notice
# ##################################################

# %%
for k in range(50,51):
    print("#"*50)
    print("source: ")
    print(embed_imput[k])
    print("Top 5  matches: ")
    for j in range(len(top_5_for_each[k][0])):
        print('Score: ', top_5_for_each[k][0][j])
        print(embed_imput[200+top_5_for_each[k][1][j]])
        
    print("#"*50)
# Out:
# ##################################################
# source:
# in course serving advertisements site thirdparty advertiser may place recognize unique cookie browser
# Top 5  matches:
# Score:  0.9763496
# in course serving advertisements site thirdparty advertiser may place recognize unique cookie browser if would like information practice know choices information used company please click
# Score:  0.9046395
# we may work thirdparty advertising companies may use information visit site order provide advertisements goods services may interest site thirdparty web sites from site companies may place recognize unique cookie computer use technologies web beacons pixel tags our privacy policy cover use information thirdparty advertisement serving company may collect for information ad cookies companies provide users ability optout collection information cookies please click
# Score:  0.89745224
# you also aware web advertising partners may place recognize unique cookie browser cookies enable advertisers determine whether seen particular advertisement for information doubleclick s privacy practices cookies optout receiving cookies please visit http wwwdoubleclicknetuscorporateprivacy for information google s privacy practices please visit http wwwgooglecomprivacyhtml
# Score:  0.89211994
# ii some third party partners including advertisers marketing services companies may set access cookies similar technologies computer well may behalf we control third parties use cookies similar technologies information derived therefrom
# Score:  0.88793784
# we may ask advertisers partners serve ads services devices may use cookies similar technologies placed us third party
# ##################################################
